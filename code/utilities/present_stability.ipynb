# %%
import seaborn as sns
import matplotlib.pyplot as plt
onered = [0.69,0.75,1,0.81,0.69,1,0.94,0.81,0.69,0.69]  # Replace with your list
onetriangle = [1,1,1,0.92,0.85,0.85,0.85,0.85,0.77,0.77]  # Replace with your list
tp = [0.75,0.75,0.70,0.70,0.70,0.70,0.65,0.60,0.60,0.60]  # Replace with your list
# sns.set(style="whitegrid")
plt.figure(figsize=(6, 4))
sns.boxplot(data={'one-red':onered,'one-triangle':onetriangle,'two-pair':tp},medianprops=dict(linewidth=2))
plt.title('Model Stability', fontsize=14)
plt.ylabel('Accuracy', fontsize=12)
# save as pdf 
plt.savefig('model_stability.pdf', bbox_inches='tight')
